# %%
import pyspark
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark import SparkContext
import random

# %%
spark = SparkSession.builder.appName("t1").getOrCreate()
sc = SparkContext.getOrCreate()

# %% [markdown]
# Theres about 9.5 million entries not 900k like whats mentioned in the pdf

# %% [markdown]
# The date and serial_number are the composite primary key so I'm going to only use those columns to make it easier to read

# %%
prefix= 'C:/Users/poona/Downloads/data_Q1_2019/drive_stats_2019_Q1/'

# %%
paths = [prefix + '2019-01-01.csv',
prefix + '2019-01-02.csv',
prefix + '2019-01-03.csv',
prefix + '2019-01-04.csv',
prefix + '2019-01-05.csv',
prefix + '2019-01-06.csv',
prefix + '2019-01-07.csv',
prefix + '2019-01-08.csv',
prefix + '2019-01-09.csv',
prefix + '2019-01-10.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

reservoir=[]
K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        if counter<K:
            reservoir.append(j)
            counter = counter + 1
        else:
            prob = K/counter
            counter = counter + 1
            if random.random() < prob:
                reservoir[random.choice(range(K))] = j

# %%
c1 = data2.count()

# %%
c1
# Out:
# 1074554

# %%
paths = [prefix + '2019-01-11.csv',
prefix + '2019-01-12.csv',
prefix + '2019-01-13.csv',
prefix + '2019-01-14.csv',
prefix + '2019-01-15.csv',
prefix + '2019-01-16.csv',
prefix + '2019-01-17.csv',
prefix + '2019-01-18.csv',
prefix + '2019-01-19.csv',
prefix + '2019-01-20.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 2140904

# %%
paths = [prefix + '2019-01-21.csv',
prefix + '2019-01-22.csv',
prefix + '2019-01-23.csv',
prefix + '2019-01-24.csv',
prefix + '2019-01-25.csv',
prefix + '2019-01-26.csv',
prefix + '2019-01-27.csv',
prefix + '2019-01-28.csv',
prefix + '2019-01-29.csv',
prefix + '2019-01-30.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)
                     
for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 3208874

# %%
paths = [prefix + '2019-01-31.csv',
prefix + '2019-02-01.csv',
prefix + '2019-02-02.csv',
prefix + '2019-02-03.csv',
prefix + '2019-02-04.csv',
prefix + '2019-02-05.csv',
prefix + '2019-02-06.csv',
prefix + '2019-02-07.csv',
prefix + '2019-02-08.csv',
prefix + '2019-02-09.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)
                           
for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 4267266

# %%
paths = [prefix + '2019-02-10.csv',
prefix + '2019-02-11.csv',
prefix + '2019-02-12.csv',
prefix + '2019-02-13.csv',
prefix + '2019-02-14.csv',
prefix + '2019-02-15.csv',
prefix + '2019-02-16.csv',
prefix + '2019-02-17.csv',
prefix + '2019-02-18.csv',
prefix + '2019-02-19.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 5321532

# %%
paths = [prefix + '2019-02-20.csv',
prefix + '2019-02-21.csv',
prefix + '2019-02-22.csv',
prefix + '2019-02-23.csv',
prefix + '2019-02-24.csv',
prefix + '2019-02-25.csv',
prefix + '2019-02-26.csv',
prefix + '2019-02-27.csv',
prefix + '2019-02-28.csv',
prefix + '2019-03-01.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 6367340

# %%
paths = [prefix + '2019-03-02.csv',
prefix + '2019-03-03.csv',
prefix + '2019-03-04.csv',
prefix + '2019-03-05.csv',
prefix + '2019-03-06.csv',
prefix + '2019-03-07.csv',
prefix + '2019-03-08.csv',
prefix + '2019-03-09.csv',
prefix + '2019-03-10.csv',
prefix + '2019-03-11.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 7443697

# %%
paths = [prefix + '2019-03-12.csv',
prefix + '2019-03-13.csv',
prefix + '2019-03-14.csv',
prefix + '2019-03-15.csv',
prefix + '2019-03-16.csv',
prefix + '2019-03-17.csv',
prefix + '2019-03-18.csv',
prefix + '2019-03-19.csv',
prefix + '2019-03-20.csv',
prefix + '2019-03-21.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
c1 = c1 + data2.count()

# %%
c1
# Out:
# 8513620

# %%
paths = [prefix + '2019-03-22.csv',
prefix + '2019-03-23.csv',
prefix + '2019-03-24.csv',
prefix + '2019-03-25.csv',
prefix + '2019-03-26.csv',
prefix + '2019-03-27.csv',
prefix + '2019-03-28.csv',
prefix + '2019-03-29.csv',
prefix + '2019-03-30.csv',
prefix + '2019-03-31.csv']

data = spark.read.csv(paths, header='true')
data.createOrReplaceTempView("data")

query = "SELECT DISTINCT date, serial_number FROM data"
data2 = spark.sql(query)
data2.createOrReplaceTempView("data2")

K=50000
counter = 0

split_weights = [1.0] * 1 #I originally was splitting the entire dataset but changed it into sections and just left this here
#Doesn't really do much but I didn't want to get rid of it because it's a useful function to remember
splits = data2.randomSplit(split_weights)

for i in range(len(splits)):
    temp=splits[i].collect() #Splitted the data into parts and it seemed safe with ~10 files, all unique rows
    for j in temp:
        prob = K/(counter + c1)
        counter = counter + 1
        if random.random() < prob:
            reservoir[random.choice(range(K))] = j

# %%
for i in reservoir:
    print(i)
# Out:
# Row(date='2019-01-21', serial_number='WD-WX11DA4DJU6K')
# Row(date='2019-03-24', serial_number='S300Z7LN')
# Row(date='2019-03-30', serial_number='S301PWTC')
# Row(date='2019-02-13', serial_number='ZA181A4D')
# Row(date='2019-01-02', serial_number='ZCH07FRE')
# Row(date='2019-01-10', serial_number='PL1331LAHBX8EH')
# Row(date='2019-02-14', serial_number='ZA13R3ZR')
# Row(date='2019-01-11', serial_number='ZJV10JC2')
# Row(date='2019-03-29', serial_number='ZCH0681M')
# Row(date='2019-01-17', serial_number='ZA16PKHR')
# Row(date='2019-01-14', serial_number='Z305GJDP')
# Row(date='2019-02-01', serial_number='PL1331LAHG5GNH')
# Row(date='2019-02-10', serial_number='ZCH078K2')
# Row(date='2019-02-02', serial_number='ZA13R487')
# Row(date='2019-02-15', serial_number='PL1331LAHE0E6H')
# Row(date='2019-02-08', serial_number='ZA153S4Q')
# Row(date='2019-01-30', serial_number='ZCH0BBRJ')
# Row(date='2019-03-13', serial_number='8CGDZ0YH')
# Row(date='2019-03-30', serial_number='ZCH0838T')
# ...
